# %% [markdown]
# **Inheritance in Python:**

# %%
class Emp:
    def __init__(self):
       print("Emp class Constructor")

# %%
class Dev(Emp):  #Emp is super or base or parent class and Dev is sub or derived or child
  def __init__(self):
    super().__init__()
    print("Dev class Constructor")

# %%
emp=Emp()
# Out:
# Emp class Constructor

# %%
dev=Dev()
# Out:
# Emp class Constructor
# Dev class Constructor

# %% [markdown]
# Example-2

# %%
class Employee:
    def __init__(self,id,name,salary):
       self.id=id
       self.name=name
       self.salary=salary
    def __str__(self):
       return f"Id={self.id},name={self.name},salary={self.salary}"

# %%
emp=Employee(1,'Sam',5600)
print(emp)
# Out:
# Id=1,name=Sam,salary=5600

# %%
class Developer(Employee):
  def __init__(self,id,name,salary,domain,project):
    super().__init__(id,name,salary)
    self.domain=domain
    self.project=project

  def __str__(self):
    return f"Id={self.id},name={self.name},salary={self.salary},domain={self.domain},project={self.project}"

# %%
dev=Developer(13,'Raj',5600,'Python','Project1')
print(dev)
# Out:
# Id=13,name=Raj,salary=5600,domain=Python,project=Project1

# %% [markdown]
# Method Overriding

# %%
class Product:
 def reg(self):
  self.pid=int(input("enter product id: \t"))
  self.pname=input("enter product name: \t")
  self.price=int(input("enter product price:\t"))
 def display(self):
  print("product id \t ",self.pid)
  print("product name \t ",self.pname)
  print("product price \t ",self.price)

# %%
class HerbalProduct(Product):
  pass

# %%
p1=Product()
p1.reg()
p1.display()
# Out:
# enter product id: 	102
# enter product name: 	Laptop
# enter product price:	2300
# product id 	  102
# product name 	  Laptop
# product price 	  2300

# %%
hp=HerbalProduct()
hp.reg()
hp.display()
# Out:
# enter product id: 	12
# enter product name: 	sad
# enter product price:	34
# product id 	  12
# product name 	  sad
# product price 	  34

# %%
#Example-3
class Product:
 def reg(self):
  self.pid=int(input("enter product id: \t"))
  self.pname=input("enter product name: \t")
  self.price=int(input("enter product price:\t"))
 def display(self):
  print("product id \t ",self.pid)
  print("product name \t ",self.pname)
  print("product price \t ",self.price)

# %%
class HerbalProduct(Product):

  def reg(self):
    super().reg()
    self.herbs_used=input("enter herbs used in product: \t")
    self.mfdate=input("enter product mfdate: \t")
    self.expdate=input("enter product expdate: \t")

  def display(self):
    super().display()
    print("Herbs used  \t ",self.herbs_used)
    print("product mfdate \t ",self.mfdate)
    print("product expdate \t ",self.expdate)

# %%
hp1=HerbalProduct()
hp1.reg()
hp1.display()
# Out:
# enter product id: 	12
# enter product name: 	herbal shampoo
# enter product price:	121
# enter herbs used in product: 	amla, ritha, sikkai
# enter product mfdate: 	12/12/2025
# enter product expdate: 	12/12/2025
# product id 	  12
# product name 	  herbal shampoo
# product price 	  121
# Herbs used  	  amla, ritha, sikkai
# product mfdate 	  12/12/2025
# product expdate 	  12/12/2025
