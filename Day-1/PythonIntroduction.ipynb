# %% [markdown]
# **Python Introduction**

# %%
print('Welcome to Python')
# Out:
# Welcome to Python

# %%
print('First Example in Python')
# Out:
# First Example in Python

# %%
#input example
username=input('Enter username:')
print('Welcome to Python: ' + username)
# Out:
# Enter username:neha
# Welcome to Python: neha

# %%
num1=12
num2=13
result=num1+num2
print(result)
# Out:
# 25

# %%
print(f'First Number {num1} and Second Number {num2} Result: {result}')
# Out:
# First Number 12 and Second Number 13 Result: 25

# %%
fnum=int(input('Enter First Number'))
snum=int(input('Enter Second Number'))
result=fnum+snum
print(f'Result after adding {fnum} and {snum} is = \t {result}')
# Out:
# Enter First Number34
# Enter Second Number12
# Result after adding 34 and 12 is = 	 46

# %%
first_name='sam'
last_name='smith'
full_name=first_name+' '+last_name
print(full_name)
# Out:
# sam smith

# %%
type(first_name)
# Out:
# str

# %%
num=12
type(num)
print(f'{num}')
print(f'Type of fnum {type(fnum)}  and snum  {type(snum)}')
# Out:
# 12
# Type of fnum <class 'int'>  and snum  <class 'int'>

# %%
my_num=12.44
type(my_num)
# Out:
# float

# %%
fnum=float(input('Enter First Number: \t'))
snum=float(input('Enter Second Number: \t'))
result=fnum+snum
print(f'Result after adding {fnum} and {snum} is = \t {result}')
# Out:
# Enter First Number: 	67.7896
# Enter Second Number: 	12.569
# Result after adding 67.7896 and 12.569 is = 	 80.3586

# %%
#Boolean or bool
is_active=True
type(is_active)
# Out:
# bool

# %%
is_active=False
type(is_active)
# Out:
# bool

# %%
print('Is Active User?',is_active)
# Out:
# Is Active User? False

# %%
print(f'Is active User? {is_active}')
# Out:
# Is active User? False

# %%
# complex type
complex_num=2+3j
print(complex_num)
type(complex_num)
# Out:
# (2+3j)
# complex

# %%
#Sqeuence Type
#1 list
#list []
list_ex=[10,20,30,40,50]
print(list_ex)
type(list_ex)
# Out:
# [10, 20, 30, 40, 50]
# list

# %%
cars=['Toyota','Hyundai','BMW','Tesla','Audi']
print(cars)
type(cars)
# Out:
# ['Toyota', 'Hyundai', 'BMW', 'Tesla', 'Audi']
# list

# %%
# Tuple
tuple_ex=(10,20,30,40,50)
print(tuple_ex)
type(tuple_ex)
# Out:
# (10, 20, 30, 40, 50)
# tuple

# %%
#set
set_ex={10,20,30,40,50}
print(set_ex)
type(set_ex)
# Out:
# {50, 20, 40, 10, 30}
# set

# %%
#range
range_ex=range(10)
print(range_ex)
type(range_ex)
# Out:
# range(0, 10)
# range

# %%
range_ex2=range(5)
print(range_ex2)
type(range_ex2)
# Out:
# range(0, 5)
# range

# %%
#Dictionary
emp={
    "id":1,
    "name":"Sam",
    "salary":20000.76
}
print(emp)
type(emp)
# Out:
# {'id': 1, 'name': 'Sam', 'salary': 20000.76}
# dict
